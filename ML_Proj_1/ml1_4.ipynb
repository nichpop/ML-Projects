# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import r2_score
import scipy.stats as stats

from sklearn.model_selection import train_test_split
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

df = pd.read_csv('class_assign_sample.csv')
x = df["x2"]
y = df["y"]

#create test and training set
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.4)

print("Training set shape: ", x_train.shape, y_train.shape)
print("Testing set shape: ", x_test.shape, y_test.shape)


#sns.scatterplot(data=df, x= df['x2'] , 
#                y= df['y']) #hue='time')
sns.scatterplot(data=df, x=x_train , y=y_train) 
  
#degree 2 polynomial fit or quadratic fit
#model = np.poly1d(np.polyfit(df['x2'],
                             #df['y'], 2))
model = np.poly1d(np.polyfit(x_train,
                             y_train, 2))
  
# polynomial line visualization
polyline = np.linspace(-60, 82, 10)
#plt.scatter(df['x2'], df['y'])
plt.scatter(x_test, y_test)
plt.plot(polyline, model(polyline))
plt.show()
  
print(model)

#plt.plot(x, y, color="blue", linewidth=3)

# r square metric
#print(r2_score(df['y'], 
#               model(df['x2'])))

print(r2_score(y_test, 
               model(x_test)))
'''
I got the equation -2.985 x2^2 + 1.584 x2 + 682.1 for the function f. Initially I tried to use a simple linear regression,
but I got a very low r score; so, I got the current equation by only considering the x2 data since it was the only set 
that did not look like noise in a scatter plot; then, since the plot of x2 and y forms a parabola, I used quadratic regression to fit a curve.
'''
# Out:
# Training set shape:  (309,) (309,)
# Testing set shape:  (207,) (207,)
#         2
# -2.989 x + 1.599 x + 694.3
# 0.9987575639258021
# '\nI got the equation -2.985 x2^2 + 1.584 x2 + 682.1 for the function f. Initially I tried to use a simple linear regression,\nbut I got a very low r score; so, I got the current equation by only considering the x2 data since it was the only set \nthat did not look like noise in a scatter plot; then, since the plot of x2 and y forms a parabola, I used quadratic regression to fit a curve.\n'
